# %% [markdown]
# # Background
#
# Machine learning models are always seen as "black box" models. From my personal experience working in the data science field I found two major issues when we use ML:
# 1. I deployed the model but I have no idea how the model produced the predictions
# 2. My clients find it hard to understand and trust the model predictions
#
# Explainable AI (XAI) emerges in the research field to solve the above problems. It is a set of processes and methods which answer the questions "how" and "why" AI systems work. In the paper [A Unified Approach to Interpreting Model Predictions](https://arxiv.org/abs/1705.07874), Lundberg and Lee proposed using SHAP (SHapley Additive exPlanations) as most consistent and reliable way to interpret a prediction model.
#
# This notebook aims to explain how SHAP works and explain the difficulties and pitfalls when using it on real-life. In particular, the reliablilty of SHAP values on an imbalanced dataset and the runtime if we need to deploy it in production.

# %% [markdown]
# # What is SHAP?
#
# SHAP is a mathematical method to explain the predictions of machine learning models. It is based on game theory, which assigns values to the features importance based on the marginal contribution of each feature.
#
# We can use an example to illustrate the concept of SHAP. Imagine we have a startup company with 3 employees. The company just made a new deal that worth \$100. How should we distribute the compensation for the three employees, namely, A, B and C? In this case, we woud need to know how much each employee has contributed. Assuming A and B worked equally hard, and C had no contribution at all. Intuitively, we would give \$50 to A and B each, and $0 to C. A mathematical and computational way to calculate this is to try all different combinations of the employees in this startup, and how much they could make. For example:
#
# - Startup with A, B and C: $100
# - Startup with A and B only: $100
# - Startup with A and C only: $0
# - Startup with A only: $0
#
# Then, we can find the weighted sum of marginal contributions for A is
#
# $$ 0.3333 \times 0 + 0.1667 \times 0 + 0.1667 \times 100 + 0.3333 \times 100 = 50 $$
#
# Similarly, B would also get $50 and C would get $0.
#
# SHAP does a similar analysis. It has a property which feature contributions must add up to the difference between the prediction of $x$ and the average of the preciction of "an average observation"
#
# $$ \sum_{j=1}^{p} \phi_j = \hat{f}(x) - E_X(\hat{f}(X))$$
#
# where $\phi_j$ is the SHAP value of feature $j \in \{1, 2, 3, ... p \}$. It means that the sum of all the feature SHAP values equals the model prediction minus the average of the model predictions on "some average observations".
#
# If we apply SHAP values on the above example, we would assume $E_X(\hat{f}(X)) = 0$ as the company would make a zero revenue if we pick any employee to work on the project alone. $\hat{f}(x) = 100$ and $ \phi_A = \phi_B = 50 $ while $ \phi_C = 0 $.
#
# Notice I put a quote on "some average observations". In practice, this is the part that makes interpreting SHAP difficult in real-life data.

# %% [markdown]
# # Illustration using code examples

# %% [markdown]
# ## Import libraries

# %%
import os
import time


from dotenv import load_dotenv
import numpy as np
import openai
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, metrics, Model, Sequential
from keras.layers import Dense, Dropout, Flatten
from keras import backend as K
import shap
from shap import KernelExplainer, DeepExplainer
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from kmodes.kprototypes import KPrototypes
from kmodes.kmodes import KModes
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
# Set seed for reproducible results
np.random.seed(1)
tf.random.set_seed(1)
shap.initjs()
load_dotenv()
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...
# True

# %% [markdown]
# ## Use ChatGPT to generate simulated data
# In this example I will use ChatGPT to generate some simulated data. I will prompt GPT to give me a csv of lattitude and longitude of cities, and train a simple neural network model to predict of a city is in Asia or not.

# %%
# Load your API key from an environment variable or secret management service
openai.api_key = os.getenv("OPENAI_API_KEY")

# Check which models I can use
for model in openai.Model.list()['data']:
    print(model['id']) if "gpt" in model['id'] else ""
# Out:
# gpt-4-0314
# gpt-3.5-turbo-16k-0613
# gpt-3.5-turbo-0301
# gpt-3.5-turbo-16k
# gpt-4
# gpt-3.5-turbo-0613
# gpt-3.5-turbo
# gpt-4-0613

# %%
def get_gpt_response(input_1):
    """Get GPT response and print on notebook cell
    Give an input and prompt gpt-4 and print the result
    Args:
        input_1 (str): The input prompt
    """
    response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=[
        {"role": "system", "content": input_1},
        ]
    )

    print(response["choices"][0]["message"]["content"])

# %%
get_gpt_response("""
Generate a csv with 3 columns: Latitude, Longitude, CityName, Continent
where Latitude and Longitude are the latitude and longitude of any city, CityName is the name of the city and Continent is the continent of the country.
Give 70 rows of the csv.
""")
# Out:
# Latitude,Longitude,CityName,Continent
# 19.0760,72.8777,Mumbai,Asia
# 48.8566,2.3522,Paris,Europe
# 40.7128,-74.0060,New York,North America
# 51.5074,-0.1278,London,Europe
# -33.9249,18.4241,Cape Town,Africa
# -23.5505,-46.6333,Sao Paulo,South America
# 35.6895,139.6917,Tokyo,Asia
# -12.4634,130.8456,Darwin,Australia
# 53.9021,27.5619,Minsk,Europe
# 36.7372,-119.7869,Fresno,North America
# 42.3601,-71.0589,Boston,North America
# -6.7924,39.2083,Dar Es Salaam,Africa
# 3.1412,101.6865,Kuala Lumpur,Asia
# -36.8485,174.7633,Auckland,Australia
# 12.9716,77.5946,Bangalore,Asia
# 32.7767,-96.7970,Dallas,North America
# -28.0473,153.4341,Gold Coast,Australia
# -33.865143,151.209900,Sydney,Australia
# -37.8136,144.9631,Melbourne,Australia
# 41.9028,12.4964,Rome,Europe
# 49.2827,-123.1207,Vancouver,North America
# 14.5995,120.9842,Manila,Asia
# 28.6139,77.2090,New Delhi,Asia
# -17.8252,31.0335,Harare,Africa
# -12.9065,-38.3210,Salvador,Brazil
# -34.6083,-58.3816,Buenos Aires,South America
# -22.9068,-43.1729,Rio de Janeiro,South America
# -15.8267,-47.9218,Brasilia,South America
# 39.9042,116.4074,Beijing,Asia
# 51.1634,6.4410,Düsseldorf,Europe
# 43.6024,1.4437,Toulouse,Europe
# 45.5017,-73.5673,Montreal,North America
# -37.4713,144.7852,Canberra,Australia
# -29.8546,31.0292,Durban,Africa
# 35.0116,135.7681,Kyoto,Asia
# 37.5665,126.9780,Seoul,Asia
# 50.4501,30.5234,Kiev,Europe
# 48.1460,11.6081,Munich,Europe
# 55.9533,-3.1883,Edinburgh,Europe
# 34.0522,-118.2437,Los Angeles,North America
# 37.7749,-122.4194,San Francisco,North America
# 13.7086,100.4566,Bangkok,Asia
# 31.9686,-99.9018,Texas,North America
# 40.7769,-73.9813,Manhattan,North America
# 47.6062,-122.3321,Seattle,North America
# 48.4284,-123.3656,Victoria,Canada
# 21.4225,39.8262,Mecca,Asia
# -1.2864,36.8172,Nairobi,Africa
# 35.4437,139.6380,Yokohama,Asia
# 34.6937,135.5022,Osaka,Asia
# 33.7489,-84.3880,Atlanta,North America
# 45.4215,-75.6972,Ottawa,North America
# -1.2921,36.8219,Nairobi,Africa
# 39.0347,-94.5875,Kansas City,North America
# 41.9022,12.4539,Vatican City,
# -35.2809,149.1300,Canberra,Australia
# 31.2113,29.9192,Alexandria,Africa
# 43.6532,-79.3832,Toronto,North America
# 35.8617,104.1954,China,Asia
# 64.1814,-51.7205,Nuuk,North America
# 38.9072,-77.0369,Washington DC,North America
# 28.2717,83.9310,Pokhara,Asia
# -34.1014,18.4565,South Africa,Africa
# 45.5505,-73.7528,Laval,North America
# 45.4215,-75.6994,Ottawa,North America
# 14.7167,17.4731,Dakar,Africa
# 15.2941,74.1240,Goa,Asia
# 39.4699,-0.3774,Valencia,Europe

# %%
get_gpt_response("""
Generate 50 more Latitude, Longitude, CityName and Continent for cities in Europe, but do not duplicate with the following:
Latitude	Longitude	CityName	Continent
48.8566	2.3522	Paris	Europe
51.5074	-0.1278	London	Europe
52.52	13.405	Berlin	Europe
41.9028	12.4964	Rome	Europe
55.7558	37.6176	Moscow	Europe
48.2082	16.3738	Vienna	Europe
52.3702	4.8952	Amsterdam	Europe
55.9532	-3.1883	Edinburgh	Europe
53.3498	-6.2603	Dublin	Europe
59.3293	18.0686	Stockholm	Europe
51.1657	10.4515	Berlin	Europe
60.472	8.4689	Oslo	Europe
52.368	4.9036	Amsterdam	Europe
41.9022	12.4853	Rome	Europe
48.1351	11.582	Munich	Europe
48.1476	17.1077	Bratislava	Europe
44.7866	20.4489	Belgrade	Europe
55.6761	12.5683	Copenhagen	Europe
61.9241	25.7482	Helsinki	Europe
47.4979	19.0402	Budapest	Europe
47.5596	7.5886	Basel	Europe
46.2276	2.2137	France	Europe
53.5511	9.9937	Hamburg	Europe
51.5085	-0.1257	London	Europe
41.0082	28.9784	Istanbul	Europe
40.4168	-3.7038	Madrid	Europe
43.6047	1.4442	Toulouse	Europe
41.3851	2.1734	Barcelona	Europe
45.764	4.8357	Lyon	Europe
60.1699	24.9384	Helsinki	Europe
37.9838	23.7275	Athens	Europe
54.66453	25.31674	Vilnius	Europe
45.4642	9.19	Milan	Europe
51.22	4.4	Antwerp	Europe
51.9225	4.47917	Rotterdam	Europe
47.3686	8.5392	Zurich	Europe
40.4637	-3.7492	Spain	Europe
59.9112	10.7522	Oslo	Europe
50.0755	14.4378	Prague	Europe

Give output in CSV format
""")
# Out:
# Latitude,Longitude,CityName,Continent
# 59.4357,24.7384,Tallinn,Europe
# 56.9506,24.1052,Riga,Europe
# 35.8997,14.5146,Valletta,Europe
# 54.3520,18.6466,Gdansk,Europe
# 53.2707,-9.0568,Galway,Europe
# 42.6977,23.3219,Sofia,Europe
# 38.7223,-9.1393,Lisbon,Europe
# 43.7384,7.4246,Monaco,Europe
# 50.6326,3.0583,Lille,Europe
# 57.1497,-2.0943,Aberdeen,Europe
# 59.8586,17.6454,Uppsala,Europe
# 60.3943,5.3221,Bergen,Europe
# 45.2671,19.8335,Novi Sad,Europe
# 58.3810,26.7196,Tartu,Europe
# 39.5696,2.6502,Palma,Europe
# 52.2297,21.0122,Warsaw,Europe
# 44.4268,26.1025,Bucharest,Europe
# 40.6406,22.9444,Thessaloniki,Europe
# 46.0569,14.5058,Ljubljana,Europe
# 45.2671,11.7690,Padua,Europe
# 51.5866,7.7642,Dortmund,Europe
# 58.5953,25.0136,Pärnu,Europe
# 50.0736,14.4180,Prague,Europe
# 38.3452,0.4810,Alicante,Europe
# 43.3208,21.8958,Niš,Europe
# 53.2194,6.5665,Groningen,Europe
# 47.1625,19.5033,Hungary,Europe
# 41.8919,12.5113,Vatican,Europe
# 61.4980,23.7610,Tampere,Europe
# 50.1109,8.6821,Frankfurt,Europe
# 43.8563,18.4131,Sarajevo,Europe
# 48.9226,24.7111,Ivano-Frankivsk,Europe
# 43.7102,7.2620,Nice,Europe
# 41.1105,20.0800,Albania,Europe
# 45.4384,10.9916,Verona,Europe
# 46.3460,15.1148,Maribor,Europe
# 54.5251,9.5509,Denmark,Europe
# 53.2206,6.5751,Russia,Europe
# 49.8153,6.1296,Luxembourg,Europe
# 35.9375,14.3754,Attard,Europe
# 41.6168,0.6222,Lleida,Europe
# 50.6145,3.0625,Roubaix,Europe
# 41.1171,16.8719,Bari,Europe
# 53.2766,-9.0693,Oranmore,Europe
# 56.4702,10.0521,Aarhus,Europe
# 50.9660,5.5008,Hasselt,Europe
# 50.6289,3.0703,Tourcoing,Europe
# 52.6659,0.1588,Wisbech,Europe
# 53.3900,-2.5969,Chester,Europe
# 36.1408,-5.3536,Gibraltar,Europe

# %% [markdown]
# I've saved the output to a csv. After some prompts I got 161 unique city locations, with imbalanced data as the records for Europe is a lot more.

# %%
# Read the csv
df = pd.read_csv('data/city_locations.csv')

# Scatter plot for Latitude and Longitude
plt.figure(figsize=(10, 8))
plt.scatter(df['Latitude'], df['Longitude'])
plt.title('Scatter plot of Latitude and Longitude')
plt.xlabel('Latitude')
plt.ylabel('Longitude')
plt.show()

# %%
# Add a new column isAsia
df['isAsia'] = df['Continent'].apply(lambda x: 1 if x == 'Asia' else 0)
# Add a column for random number as dummy feature
df['Random_1'] = np.random.rand(len(df))

# Separate into training, validation, and test dataset
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)
train_df, val_df = train_test_split(train_df, test_size=0.25, random_state=42)  # 0.25 x 0.8 = 0.2

# print the datasets
print("Training dataset:")
print(train_df.head())
print(train_df['isAsia'].value_counts())
print("\nValidation dataset:")
print(val_df['isAsia'].value_counts())
print("\nTest dataset:")
print(test_df['isAsia'].value_counts())
# Out:
# Training dataset:
#      Latitude  Longitude   CityName Continent  isAsia  Random_1
# 92    -8.0578    34.8821     Recife    Brazil       0  0.449912
# 140   60.1282    18.6435      Gävle    Europe       0  0.556240
# 5     35.6895   139.6917      Tokyo      Asia       1  0.092339
# 151   46.4881    30.7412     Odessa    Europe       0  0.967276
# 59    13.4065    74.4918  Mangalore      Asia       1  0.699758
# isAsia
# 0    83
# 1    13
# Name: count, dtype: int64
#
# Validation dataset:
# isAsia
# 0    27
# 1     5
# Name: count, dtype: int64
#
# Test dataset:
# isAsia
# 0    23
# 1    10
# Name: count, dtype: int64

# %%
# Prepare train, val, test datasets for features and truth labels
all_features = ['Latitude', 'Longitude', 'Random_1']

X_train = train_df[all_features].to_numpy()
Y_train = train_df['isAsia'].to_numpy()
X_train = X_train.astype('float32')
X_val = val_df[all_features].to_numpy()
X_val = X_val.astype('float32')
Y_val = val_df['isAsia'].to_numpy()
X_test = test_df[all_features].to_numpy()
X_test = X_test.astype('float32')
Y_test = test_df['isAsia'].to_numpy()

# %% [markdown]
# ## Build model

# %%
METRICS = [
    keras.metrics.TruePositives(name='tp'),
    keras.metrics.FalsePositives(name='fp'),
    keras.metrics.TrueNegatives(name='tn'),
    keras.metrics.FalseNegatives(name='fn'),
    keras.metrics.Accuracy(name='accuracy'),
    keras.metrics.BinaryAccuracy(name='binary_accuracy'),
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall'),
    keras.metrics.AUC(name='auc')
]
# Out:
# Metal device set to: Apple M2
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
# 2023-07-22 16:13:17.547477: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-07-22 16:13:17.547684: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
# Weighted binary crossentropy is used for the imbalanced data training

class WeightedBinaryCrossEntropy(tf.keras.losses.Loss):
    def __init__(self, ratio: float):
        """
        Args:
            ratio (float): the multiplier of positive examples weights over negative examples
        """
        
        super().__init__()
        self.ratio = ratio
        
    def call(self, y_true, y_pred):
        y_true = tf.cast(y_true, tf.float32)
        y_pred = tf.cast(y_pred, tf.float32)
        ratio = tf.convert_to_tensor(self.ratio, dtype=tf.float32)
        weights = (y_true * ratio) + tf.convert_to_tensor(1., dtype=tf.float32)
        
        bce = K.binary_crossentropy(y_true, y_pred)
        weighted_bce = K.mean(bce * weights)
        return weighted_bce

# %%
# Build a simple neural network model

INPUT_COLS = len(X_train[0])

input_shape = (None, INPUT_COLS)

model = Sequential()
model.add(Flatten())
model.add(Dense(16, 
                 activation='relu',
                 input_shape=input_shape,
               ))
model.add(Dense(8, 
                 activation='relu',
               ))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss=WeightedBinaryCrossEntropy(ratio=2.0),
              metrics=[METRICS])

# %%
# Train model

EPOCHS = 100

history = model.fit(X_train, Y_train, batch_size=32, epochs=EPOCHS, validation_data=(X_val, Y_val))
# Out:
# Epoch 1/100
# 2023-07-22 16:20:10.845518: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/3 [=========>....................] - ETA: 1s - loss: 18.7191 - tp: 5.0000 - fp: 3.0000 - tn: 49.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8438 - precision: 0.6250 - recall: 0.4167 - auc: 0.5577
# 2023-07-22 16:20:11.440821: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 3/3 [==============================] - 2s 277ms/step - loss: 9.4708 - tp: 6.0000 - fp: 21.0000 - tn: 89.0000 - fn: 12.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7422 - precision: 0.2222 - recall: 0.3333 - auc: 0.4932 - val_loss: 8.5343 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 2/100
# 3/3 [==============================] - 0s 31ms/step - loss: 5.4066 - tp: 2.0000 - fp: 21.0000 - tn: 62.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6667 - precision: 0.0870 - recall: 0.1538 - auc: 0.4486 - val_loss: 8.1963 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 3/100
# 3/3 [==============================] - 0s 27ms/step - loss: 6.1422 - tp: 3.0000 - fp: 21.0000 - tn: 62.0000 - fn: 10.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6771 - precision: 0.1250 - recall: 0.2308 - auc: 0.4731 - val_loss: 7.8761 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 4/100
# 3/3 [==============================] - 0s 28ms/step - loss: 5.9210 - tp: 2.0000 - fp: 24.0000 - tn: 59.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6354 - precision: 0.0769 - recall: 0.1538 - auc: 0.5440 - val_loss: 7.5480 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 5/100
# 3/3 [==============================] - 0s 27ms/step - loss: 6.2385 - tp: 3.0000 - fp: 22.0000 - tn: 61.0000 - fn: 10.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6667 - precision: 0.1200 - recall: 0.2308 - auc: 0.5422 - val_loss: 7.2152 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 6/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3.4260 - tp: 4.0000 - fp: 13.0000 - tn: 70.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.2353 - recall: 0.3077 - auc: 0.5950 - val_loss: 6.8845 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 7/100
# 3/3 [==============================] - 0s 26ms/step - loss: 9.3747 - tp: 2.0000 - fp: 20.0000 - tn: 63.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6771 - precision: 0.0909 - recall: 0.1538 - auc: 0.3350 - val_loss: 6.5757 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 8/100
# 3/3 [==============================] - 0s 25ms/step - loss: 4.5953 - tp: 4.0000 - fp: 17.0000 - tn: 66.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7292 - precision: 0.1905 - recall: 0.3077 - auc: 0.5375 - val_loss: 6.2968 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 9/100
# 3/3 [==============================] - 0s 23ms/step - loss: 5.9974 - tp: 2.0000 - fp: 20.0000 - tn: 63.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6771 - precision: 0.0909 - recall: 0.1538 - auc: 0.3851 - val_loss: 6.0192 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 10/100
# 3/3 [==============================] - 0s 27ms/step - loss: 4.3986 - tp: 4.0000 - fp: 18.0000 - tn: 65.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7188 - precision: 0.1818 - recall: 0.3077 - auc: 0.5389 - val_loss: 5.7533 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 11/100
# 3/3 [==============================] - 0s 28ms/step - loss: 5.2017 - tp: 5.0000 - fp: 19.0000 - tn: 64.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7188 - precision: 0.2083 - recall: 0.3846 - auc: 0.5399 - val_loss: 5.5006 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 12/100
# 3/3 [==============================] - 0s 32ms/step - loss: 4.7127 - tp: 3.0000 - fp: 16.0000 - tn: 67.0000 - fn: 10.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7292 - precision: 0.1579 - recall: 0.2308 - auc: 0.4615 - val_loss: 5.2422 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1667
# Epoch 13/100
# 3/3 [==============================] - 0s 32ms/step - loss: 5.7022 - tp: 2.0000 - fp: 18.0000 - tn: 65.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6979 - precision: 0.1000 - recall: 0.1538 - auc: 0.5273 - val_loss: 4.9698 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1852
# Epoch 14/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.0697 - tp: 5.0000 - fp: 11.0000 - tn: 72.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3125 - recall: 0.3846 - auc: 0.7576 - val_loss: 4.7359 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1852
# Epoch 15/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3.5800 - tp: 6.0000 - fp: 16.0000 - tn: 67.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2727 - recall: 0.4615 - auc: 0.5538 - val_loss: 4.5322 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.1852
# Epoch 16/100
# 3/3 [==============================] - 0s 25ms/step - loss: 4.1170 - tp: 3.0000 - fp: 18.0000 - tn: 65.0000 - fn: 10.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7083 - precision: 0.1429 - recall: 0.2308 - auc: 0.5171 - val_loss: 4.3163 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2037
# Epoch 17/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2.2936 - tp: 8.0000 - fp: 13.0000 - tn: 70.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8125 - precision: 0.3810 - recall: 0.6154 - auc: 0.7201 - val_loss: 4.1283 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2222
# Epoch 18/100
# 3/3 [==============================] - 0s 25ms/step - loss: 4.6069 - tp: 4.0000 - fp: 15.0000 - tn: 68.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2105 - recall: 0.3077 - auc: 0.5649 - val_loss: 3.9243 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2222
# Epoch 19/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.8102 - tp: 2.0000 - fp: 17.0000 - tn: 66.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7083 - precision: 0.1053 - recall: 0.1538 - auc: 0.5853 - val_loss: 3.7322 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2222
# Epoch 20/100
# 3/3 [==============================] - 0s 24ms/step - loss: 4.3440 - tp: 5.0000 - fp: 16.0000 - tn: 67.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2381 - recall: 0.3846 - auc: 0.5468 - val_loss: 3.5626 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2222
# Epoch 21/100
# 3/3 [==============================] - 0s 24ms/step - loss: 3.0314 - tp: 7.0000 - fp: 15.0000 - tn: 68.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.3182 - recall: 0.5385 - auc: 0.6399 - val_loss: 3.3825 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2222
# Epoch 22/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3.7291 - tp: 2.0000 - fp: 15.0000 - tn: 68.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7292 - precision: 0.1176 - recall: 0.1538 - auc: 0.5853 - val_loss: 3.2290 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2889
# Epoch 23/100
# 3/3 [==============================] - 0s 25ms/step - loss: 4.3240 - tp: 2.0000 - fp: 21.0000 - tn: 62.0000 - fn: 11.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.6667 - precision: 0.0870 - recall: 0.1538 - auc: 0.4425 - val_loss: 3.0542 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2481
# Epoch 24/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.9096 - tp: 6.0000 - fp: 11.0000 - tn: 72.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8125 - precision: 0.3529 - recall: 0.4615 - auc: 0.7076 - val_loss: 2.8913 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.2444
# Epoch 25/100
# 3/3 [==============================] - 0s 24ms/step - loss: 2.9161 - tp: 4.0000 - fp: 16.0000 - tn: 67.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7396 - precision: 0.2000 - recall: 0.3077 - auc: 0.5788 - val_loss: 2.7392 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.3370
# Epoch 26/100
# 3/3 [==============================] - 0s 38ms/step - loss: 1.3557 - tp: 6.0000 - fp: 18.0000 - tn: 65.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7396 - precision: 0.2500 - recall: 0.4615 - auc: 0.7122 - val_loss: 2.5934 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4111
# Epoch 27/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.5485 - tp: 6.0000 - fp: 15.0000 - tn: 68.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.2857 - recall: 0.4615 - auc: 0.5741 - val_loss: 2.4442 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4593
# Epoch 28/100
# 3/3 [==============================] - 0s 25ms/step - loss: 3.1379 - tp: 3.0000 - fp: 18.0000 - tn: 65.0000 - fn: 10.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7083 - precision: 0.1429 - recall: 0.2308 - auc: 0.5811 - val_loss: 2.3065 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.4815
# Epoch 29/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.5934 - tp: 5.0000 - fp: 15.0000 - tn: 68.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2500 - recall: 0.3846 - auc: 0.5755 - val_loss: 2.1686 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5333
# Epoch 30/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4332 - tp: 8.0000 - fp: 11.0000 - tn: 72.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8333 - precision: 0.4211 - recall: 0.6154 - auc: 0.7335 - val_loss: 2.0277 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.5963
# Epoch 31/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.7247 - tp: 5.0000 - fp: 16.0000 - tn: 67.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2381 - recall: 0.3846 - auc: 0.5806 - val_loss: 1.8876 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6407
# Epoch 32/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.7662 - tp: 7.0000 - fp: 17.0000 - tn: 66.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2917 - recall: 0.5385 - auc: 0.6627 - val_loss: 1.7593 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.6630
# Epoch 33/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.3111 - tp: 5.0000 - fp: 13.0000 - tn: 70.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.2778 - recall: 0.3846 - auc: 0.6580 - val_loss: 1.6403 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7296
# Epoch 34/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4973 - tp: 6.0000 - fp: 16.0000 - tn: 67.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2727 - recall: 0.4615 - auc: 0.6803 - val_loss: 1.5196 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7481
# Epoch 35/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.4590 - tp: 5.0000 - fp: 13.0000 - tn: 70.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.2778 - recall: 0.3846 - auc: 0.6900 - val_loss: 1.4051 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.7630
# Epoch 36/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1109 - tp: 6.0000 - fp: 17.0000 - tn: 66.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2609 - recall: 0.4615 - auc: 0.7057 - val_loss: 1.2926 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8259
# Epoch 37/100
# 3/3 [==============================] - 0s 33ms/step - loss: 1.0471 - tp: 7.0000 - fp: 17.0000 - tn: 66.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2917 - recall: 0.5385 - auc: 0.7994 - val_loss: 1.1865 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.8593
# Epoch 38/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9943 - tp: 9.0000 - fp: 15.0000 - tn: 68.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3750 - recall: 0.6923 - auc: 0.7451 - val_loss: 1.0921 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9000
# Epoch 39/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.2898 - tp: 7.0000 - fp: 18.0000 - tn: 65.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2800 - recall: 0.5385 - auc: 0.6900 - val_loss: 1.0057 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9185
# Epoch 40/100
# 3/3 [==============================] - 0s 25ms/step - loss: 2.2797 - tp: 4.0000 - fp: 12.0000 - tn: 71.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.2500 - recall: 0.3077 - auc: 0.5690 - val_loss: 0.9004 - val_tp: 0.0000e+00 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 5.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8438 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_auc: 0.9481
# Epoch 41/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5863 - tp: 10.0000 - fp: 11.0000 - tn: 72.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8542 - precision: 0.4762 - recall: 0.7692 - auc: 0.8837 - val_loss: 0.8117 - val_tp: 1.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 4.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.2000 - val_auc: 0.9556
# Epoch 42/100
# 3/3 [==============================] - 0s 31ms/step - loss: 1.2642 - tp: 6.0000 - fp: 16.0000 - tn: 67.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2727 - recall: 0.4615 - auc: 0.7433 - val_loss: 0.7303 - val_tp: 1.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 4.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.8750 - val_precision: 1.0000 - val_recall: 0.2000 - val_auc: 0.9852
# Epoch 43/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8821 - tp: 7.0000 - fp: 19.0000 - tn: 64.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7396 - precision: 0.2692 - recall: 0.5385 - auc: 0.7882 - val_loss: 0.6595 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 3.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9062 - val_precision: 1.0000 - val_recall: 0.4000 - val_auc: 0.9852
# Epoch 44/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0886 - tp: 7.0000 - fp: 14.0000 - tn: 69.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3333 - recall: 0.5385 - auc: 0.7641 - val_loss: 0.5912 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 3.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9062 - val_precision: 1.0000 - val_recall: 0.4000 - val_auc: 0.9926
# Epoch 45/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1787 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.7887 - val_loss: 0.5309 - val_tp: 2.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 3.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9062 - val_precision: 1.0000 - val_recall: 0.4000 - val_auc: 1.0000
# Epoch 46/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.3186 - tp: 5.0000 - fp: 15.0000 - tn: 68.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2500 - recall: 0.3846 - auc: 0.7493 - val_loss: 0.4767 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 47/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.6624 - tp: 9.0000 - fp: 14.0000 - tn: 69.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8125 - precision: 0.3913 - recall: 0.6923 - auc: 0.8489 - val_loss: 0.4349 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 48/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.1362 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.8230 - val_loss: 0.3982 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 49/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.8912 - tp: 6.0000 - fp: 14.0000 - tn: 69.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.3000 - recall: 0.4615 - auc: 0.7938 - val_loss: 0.3611 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 50/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6895 - tp: 8.0000 - fp: 18.0000 - tn: 65.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.3077 - recall: 0.6154 - auc: 0.8313 - val_loss: 0.3309 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 51/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5371 - tp: 9.0000 - fp: 12.0000 - tn: 71.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8333 - precision: 0.4286 - recall: 0.6923 - auc: 0.8957 - val_loss: 0.3049 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 52/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9758 - tp: 6.0000 - fp: 16.0000 - tn: 67.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.2727 - recall: 0.4615 - auc: 0.7502 - val_loss: 0.2868 - val_tp: 3.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 2.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9375 - val_precision: 1.0000 - val_recall: 0.6000 - val_auc: 1.0000
# Epoch 53/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.1782 - tp: 5.0000 - fp: 16.0000 - tn: 67.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2381 - recall: 0.3846 - auc: 0.7627 - val_loss: 0.2706 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 1.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.8000 - val_auc: 1.0000
# Epoch 54/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0150 - tp: 6.0000 - fp: 15.0000 - tn: 68.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.2857 - recall: 0.4615 - auc: 0.8244 - val_loss: 0.2546 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 1.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.8000 - val_auc: 1.0000
# Epoch 55/100
# 3/3 [==============================] - 0s 25ms/step - loss: 1.0547 - tp: 4.0000 - fp: 15.0000 - tn: 68.0000 - fn: 9.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2105 - recall: 0.3077 - auc: 0.7451 - val_loss: 0.2406 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 1.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.8000 - val_auc: 1.0000
# Epoch 56/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0575 - tp: 7.0000 - fp: 16.0000 - tn: 67.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.3043 - recall: 0.5385 - auc: 0.7905 - val_loss: 0.2281 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 1.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.8000 - val_auc: 1.0000
# Epoch 57/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.4757 - tp: 10.0000 - fp: 16.0000 - tn: 67.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3846 - recall: 0.7692 - auc: 0.8962 - val_loss: 0.2185 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 1.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.8000 - val_auc: 1.0000
# Epoch 58/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.7483 - tp: 5.0000 - fp: 13.0000 - tn: 70.0000 - fn: 8.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.2778 - recall: 0.3846 - auc: 0.7878 - val_loss: 0.2094 - val_tp: 4.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 1.0000 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 0.9688 - val_precision: 1.0000 - val_recall: 0.8000 - val_auc: 1.0000
# Epoch 59/100
# 3/3 [==============================] - 0s 42ms/step - loss: 0.4539 - tp: 11.0000 - fp: 14.0000 - tn: 69.0000 - fn: 2.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8333 - precision: 0.4400 - recall: 0.8462 - auc: 0.8999 - val_loss: 0.2027 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 60/100
# 3/3 [==============================] - 0s 26ms/step - loss: 1.0551 - tp: 7.0000 - fp: 15.0000 - tn: 68.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.3182 - recall: 0.5385 - auc: 0.7790 - val_loss: 0.1996 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 61/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5663 - tp: 7.0000 - fp: 15.0000 - tn: 68.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.3182 - recall: 0.5385 - auc: 0.8596 - val_loss: 0.1975 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 62/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5770 - tp: 8.0000 - fp: 19.0000 - tn: 64.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7500 - precision: 0.2963 - recall: 0.6154 - auc: 0.8545 - val_loss: 0.1946 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 63/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3727 - tp: 10.0000 - fp: 11.0000 - tn: 72.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8542 - precision: 0.4762 - recall: 0.7692 - auc: 0.9291 - val_loss: 0.1898 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 64/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8589 - tp: 9.0000 - fp: 17.0000 - tn: 66.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.3462 - recall: 0.6923 - auc: 0.8387 - val_loss: 0.1852 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 65/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4415 - tp: 10.0000 - fp: 14.0000 - tn: 69.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8229 - precision: 0.4167 - recall: 0.7692 - auc: 0.9096 - val_loss: 0.1817 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 66/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.9107 - tp: 7.0000 - fp: 16.0000 - tn: 67.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.3043 - recall: 0.5385 - auc: 0.8197 - val_loss: 0.1778 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 67/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.3682 - tp: 11.0000 - fp: 14.0000 - tn: 69.0000 - fn: 2.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8333 - precision: 0.4400 - recall: 0.8462 - auc: 0.9300 - val_loss: 0.1734 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 68/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.4649 - tp: 10.0000 - fp: 16.0000 - tn: 67.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3846 - recall: 0.7692 - auc: 0.8892 - val_loss: 0.1706 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 69/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6117 - tp: 6.0000 - fp: 15.0000 - tn: 68.0000 - fn: 7.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.2857 - recall: 0.4615 - auc: 0.8360 - val_loss: 0.1685 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 70/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5260 - tp: 8.0000 - fp: 14.0000 - tn: 69.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3636 - recall: 0.6154 - auc: 0.8536 - val_loss: 0.1653 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 71/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.4116 - tp: 10.0000 - fp: 11.0000 - tn: 72.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8542 - precision: 0.4762 - recall: 0.7692 - auc: 0.9171 - val_loss: 0.1620 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 72/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4800 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.8777 - val_loss: 0.1590 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 73/100
# 3/3 [==============================] - 0s 29ms/step - loss: 0.8830 - tp: 6.0000 - fp: 12.0000 - tn: 71.0000 - fn: 7.0000 - accuracy: 0.0104 - binary_accuracy: 0.8021 - precision: 0.3333 - recall: 0.4615 - auc: 0.8063 - val_loss: 0.1551 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 74/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5178 - tp: 9.0000 - fp: 17.0000 - tn: 66.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7812 - precision: 0.3462 - recall: 0.6923 - auc: 0.8591 - val_loss: 0.1503 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 75/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.5130 - tp: 11.0000 - fp: 15.0000 - tn: 68.0000 - fn: 2.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8229 - precision: 0.4231 - recall: 0.8462 - auc: 0.8911 - val_loss: 0.1477 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 76/100
# 3/3 [==============================] - 0s 46ms/step - loss: 0.8495 - tp: 8.0000 - fp: 18.0000 - tn: 65.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7604 - precision: 0.3077 - recall: 0.6154 - auc: 0.8211 - val_loss: 0.1459 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 77/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4437 - tp: 9.0000 - fp: 13.0000 - tn: 70.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8229 - precision: 0.4091 - recall: 0.6923 - auc: 0.9013 - val_loss: 0.1438 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 78/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.8188 - tp: 9.0000 - fp: 13.0000 - tn: 70.0000 - fn: 4.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8229 - precision: 0.4091 - recall: 0.6923 - auc: 0.8234 - val_loss: 0.1416 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 79/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.8368 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.8318 - val_loss: 0.1403 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 80/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4409 - tp: 7.0000 - fp: 18.0000 - tn: 65.0000 - fn: 6.0000 - accuracy: 0.0104 - binary_accuracy: 0.7500 - precision: 0.2800 - recall: 0.5385 - auc: 0.8883 - val_loss: 0.1385 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 81/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.7307 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.8489 - val_loss: 0.1370 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 82/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4291 - tp: 7.0000 - fp: 18.0000 - tn: 65.0000 - fn: 6.0000 - accuracy: 0.0104 - binary_accuracy: 0.7500 - precision: 0.2800 - recall: 0.5385 - auc: 0.8874 - val_loss: 0.1354 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 83/100
# 3/3 [==============================] - 0s 40ms/step - loss: 0.7090 - tp: 8.0000 - fp: 14.0000 - tn: 69.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3636 - recall: 0.6154 - auc: 0.8554 - val_loss: 0.1335 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 84/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4938 - tp: 7.0000 - fp: 16.0000 - tn: 67.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7708 - precision: 0.3043 - recall: 0.5385 - auc: 0.8647 - val_loss: 0.1317 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 85/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3814 - tp: 10.0000 - fp: 16.0000 - tn: 67.0000 - fn: 3.0000 - accuracy: 0.0104 - binary_accuracy: 0.8021 - precision: 0.3846 - recall: 0.7692 - auc: 0.9268 - val_loss: 0.1312 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 86/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3970 - tp: 8.0000 - fp: 14.0000 - tn: 69.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3636 - recall: 0.6154 - auc: 0.9027 - val_loss: 0.1306 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 87/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4436 - tp: 10.0000 - fp: 16.0000 - tn: 67.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3846 - recall: 0.7692 - auc: 0.8865 - val_loss: 0.1303 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 88/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5044 - tp: 5.0000 - fp: 14.0000 - tn: 69.0000 - fn: 8.0000 - accuracy: 0.0104 - binary_accuracy: 0.7708 - precision: 0.2632 - recall: 0.3846 - auc: 0.8563 - val_loss: 0.1304 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 89/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4108 - tp: 10.0000 - fp: 15.0000 - tn: 68.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8125 - precision: 0.4000 - recall: 0.7692 - auc: 0.9069 - val_loss: 0.1301 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 90/100
# 3/3 [==============================] - 0s 48ms/step - loss: 0.2930 - tp: 11.0000 - fp: 15.0000 - tn: 68.0000 - fn: 2.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8229 - precision: 0.4231 - recall: 0.8462 - auc: 0.9555 - val_loss: 0.1299 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 91/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3907 - tp: 10.0000 - fp: 14.0000 - tn: 69.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8229 - precision: 0.4167 - recall: 0.7692 - auc: 0.9222 - val_loss: 0.1297 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 92/100
# 3/3 [==============================] - 0s 24ms/step - loss: 0.2617 - tp: 12.0000 - fp: 11.0000 - tn: 72.0000 - fn: 1.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8750 - precision: 0.5217 - recall: 0.9231 - auc: 0.9727 - val_loss: 0.1290 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 93/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.5733 - tp: 10.0000 - fp: 11.0000 - tn: 72.0000 - fn: 3.0000 - accuracy: 0.0104 - binary_accuracy: 0.8542 - precision: 0.4762 - recall: 0.7692 - auc: 0.8990 - val_loss: 0.1282 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 94/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.4634 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.8865 - val_loss: 0.1273 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 95/100
# 3/3 [==============================] - 0s 25ms/step - loss: 0.7603 - tp: 8.0000 - fp: 16.0000 - tn: 67.0000 - fn: 5.0000 - accuracy: 0.0104 - binary_accuracy: 0.7812 - precision: 0.3333 - recall: 0.6154 - auc: 0.8040 - val_loss: 0.1274 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 96/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.6971 - tp: 8.0000 - fp: 15.0000 - tn: 68.0000 - fn: 5.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.7917 - precision: 0.3478 - recall: 0.6154 - auc: 0.8605 - val_loss: 0.1272 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 97/100
# 3/3 [==============================] - 0s 41ms/step - loss: 0.7117 - tp: 7.0000 - fp: 13.0000 - tn: 70.0000 - fn: 6.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8021 - precision: 0.3500 - recall: 0.5385 - auc: 0.8614 - val_loss: 0.1274 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 98/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.3290 - tp: 12.0000 - fp: 15.0000 - tn: 68.0000 - fn: 1.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8333 - precision: 0.4444 - recall: 0.9231 - auc: 0.9449 - val_loss: 0.1270 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 99/100
# 3/3 [==============================] - 0s 26ms/step - loss: 0.4200 - tp: 11.0000 - fp: 15.0000 - tn: 68.0000 - fn: 2.0000 - accuracy: 0.0104 - binary_accuracy: 0.8229 - precision: 0.4231 - recall: 0.8462 - auc: 0.9092 - val_loss: 0.1263 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000
# Epoch 100/100
# 3/3 [==============================] - 0s 31ms/step - loss: 0.3674 - tp: 10.0000 - fp: 15.0000 - tn: 68.0000 - fn: 3.0000 - accuracy: 0.0000e+00 - binary_accuracy: 0.8125 - precision: 0.4000 - recall: 0.7692 - auc: 0.9184 - val_loss: 0.1251 - val_tp: 5.0000 - val_fp: 0.0000e+00 - val_tn: 27.0000 - val_fn: 0.0000e+00 - val_accuracy: 0.0000e+00 - val_binary_accuracy: 1.0000 - val_precision: 1.0000 - val_recall: 1.0000 - val_auc: 1.0000

# %%
# See model summary
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (32, 3)                   0
#
#  dense_3 (Dense)             (32, 16)                  64
#
#  dense_4 (Dense)             (32, 8)                   136
#
#  dropout_1 (Dropout)         (32, 8)                   0
#
#  dense_5 (Dense)             (32, 1)                   9
#
# =================================================================
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Save the entire model as a SavedModel.
# !mkdir -p saved_model
model.save('saved_model/sample_model')
# Out:
# INFO:tensorflow:Assets written to: saved_model/sample_model/assets

# %%
def plot_graphs(history, string):
    """ Plot graphs on the model training history
    Args:
        history (keras.callbacks.History): output from the keras model after fitting
        string (str): The metrics for evaluation
    """
    plt.plot(history.history[string])
    plt.plot(history.history['val_'+string])
    plt.xlabel("Epochs")
    plt.ylabel(string)
    plt.legend([string, 'val_'+string])
    plt.show()

# %%
# Check model training history
plot_graphs(history, "binary_accuracy")
plot_graphs(history, "recall")

# %% [markdown]
# ## Get model predictions

# %%
predictions = model.predict(X_test)
predicted_probabilities = [pred[0] for pred in predictions]
test_df['predicted_probability'] = predicted_probabilities
test_df["pred"] = (test_df["predicted_probability"] > 0.5).astype(int)
# Out:
# 1/2 [==============>...............] - ETA: 0s
# 2023-07-22 16:36:12.657757: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 2/2 [==============================] - 0s 301ms/step

# %%
pred_table = test_df[['isAsia','pred', 'predicted_probability']]

# Accuracy matrix
y_true_label = pred_table['isAsia']
predict_valid_label = pred_table['pred']
proba_pred = pred_table['predicted_probability']

accuracy_matrix = confusion_matrix(y_true_label, predict_valid_label)

# Confusion Matrix Heatmap
acc_df = pd.DataFrame(accuracy_matrix)
ax = sns.heatmap(acc_df,  fmt=".1f",
         cmap='Blues',annot=True)
# X - Y axis labels
ax.set_ylabel('Truth')
ax.set_xlabel('Model Prediction')
# Out:
# Text(0.5, 23.52222222222222, 'Model Prediction')

# %%
# Plotting model predictions on the original test dataset
fp_df = test_df[(test_df['isAsia']==0) & (test_df['pred']==1)]
tp_df = test_df[(test_df['isAsia']==1) & (test_df['pred']==1)]
tn_df = test_df[(test_df['isAsia']==0) & (test_df['pred']==0)]

plt.scatter(tn_df['Latitude'], tn_df['Longitude'], label="True Negatives", alpha=0.5)
plt.scatter(tp_df['Latitude'], tp_df['Longitude'], label="True Positives", alpha=0.5)
plt.scatter(fp_df['Latitude'], fp_df['Longitude'], label="False Positives", alpha=0.5)
plt.title('Latitude and Longitude')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %% [markdown]
# Now, we have a model trained on simulated imbalance data with no false negatives. This is a typical situation in business as we apply ML in fields such as fraud detection, where truth labels are very limited but the cost of having any false negative is high.

# %% [markdown]
# ## Typical use of Kernel Explainer
#
# Kernel SHAP is a model agnostic algorithm - it applies to all the predictors. It is reliable and easy to use, however, the computation can be slow when the baseline dataset is huge. Using a sample/ the entire of the training data as the baseline is a common practice, as it represents a general view of the data and we can compare the model prediction of some instances with the general data.

# %%
def get_predictions(current_predictor, data_ds):
    """Function to get predictions using a model predictor and data.
    Args:
        current_predictor (keras.engine.sequential.Sequential): the trained model ready for predicitons
        data_ds (dataframe): dataset for prediction
    """
    predictions = current_predictor.predict(data_ds)
    return np.array(predictions, dtype='float64')


def f(X):
    """Same notation as the above formula.
    f(X) is the model prediction on X
    Args:
        X (dataframe): data for prediction
    """
    return get_predictions(model, X)


# Sample predictions
f(X_test[:5])
# Out:
# 1/1 [==============================] - 0s 19ms/step
# array([[0.58508629],
#        [0.01664158],
#        [0.1233336 ],
#        [0.87183952],
#        [0.55258703]])

# %%
# Define background sample
# Use the whole train dataset as background
background_sample = train_df[all_features]
print(background_sample.shape)
background_sample.head()
# Out:
# (96, 3)
#      Latitude  Longitude  Random_1
# 92    -8.0578    34.8821  0.449912
# 140   60.1282    18.6435  0.556240
# 5     35.6895   139.6917  0.092339
# 151   46.4881    30.7412  0.967276
# 59    13.4065    74.4918  0.699758

# %%
# Make a SHAP Kernel Explainer
# The first argument is the function for f(X)
# The second argument is the background data for E(f(X))
kernel_explainer = KernelExplainer(
    f,
    background_sample.to_numpy(),
)
# Out:
# 3/3 [==============================] - 0s 9ms/step

# %%
# Check expected value of the baseline predictions
print(f"The expected value of Kernel explainer with whole training dataset as baseline: {kernel_explainer.expected_value[0]}")
# Out:
# The expected value of Kernel explainer with whole training dataset as baseline: 0.1483616053422046

# %% [markdown]
# This expected value is consistent with our simulated data construction. We have an imbalnced dataset so if we pick any random observation we would expect the probability of it being an Asian country close to zero.

# %%
# Pick a positive sample to see the model explanations
sample = test_df[(test_df['isAsia'] == 1) & (test_df['pred'] == 1)][all_features].sample(1)
sample
# Out:
#     Latitude  Longitude  Random_1
# 60   13.0827    80.2707  0.102334

# %%
shap_values = kernel_explainer.shap_values(sample.to_numpy())
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 23ms/step
# 18/18 [==============================] - 0s 2ms/step

# %%
# Plot the shap values
shap.force_plot(kernel_explainer.expected_value, shap_values[0], sample)
# Out:
# <div id='iZ4ACNKGORM5TIMVZB8TW'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.1483616053422046, "outValue": 0.7731871008872986, "link": "identity", "featureNames": ["Latitude", "Longitude", "Random_1"], "features": {"0": {"effect": 0.25038445776772156, "value": 13.0827}, "1": {"effect": 0.3766432320588353, "value": 80.2707}, "2": {"effect": -0.0022021942814628437, "value": 0.10233442882782584}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iZ4ACNKGORM5TIMVZB8TW')
#   );
# </script>

# %%
# SHAP values 
pd.DataFrame(data=shap_values[0], columns=all_features)
# Out:
#    Latitude  Longitude  Random_1
# 0  0.250384   0.376643 -0.002202

# %% [markdown]
# It looks like for this particular instance, the model finds Longitude more important than the Latitude in making its prediction. Let's further take a look at the Global SHAP.

# %% [markdown]
# ## Global SHAP

# %%
def global_shap_plot(values, headers):
    """Function to plot Global SHAP
    Args:
        values (dataframe): SHAP values of all the data
        headers (str): Plot title
    """
    plt.rcdefaults()
    fig, ax = plt.subplots()
    y_pos = np.arange(len(headers))
    ax.barh(y_pos, values, align='center')
    ax.set_yticks(y_pos, labels=headers)
    ax.invert_yaxis()  # labels read top-to-bottom
    ax.set_xlabel('Global SHAP values')
    ax.set_title('Global SHAP Plot')

    plt.show()

# %%
start_time = time.time()
all_shap_values = kernel_explainer.shap_values(X_test)
end_time = time.time()
print(
    f"Computing SHAP for {X_test.shape[0]} records used time: {end_time - start_time} seconds"
)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 17ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 11ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 16ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 12ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 10ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 8ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# 1/1 [==============================] - 0s 9ms/step
# 18/18 [==============================] - 0s 1ms/step
# Computing SHAP for 33 records used time: 3.0761427879333496 seconds

# %%
all_shaps_df = pd.DataFrame(data=all_shap_values[0], columns=all_features)
# Compute global SHAP: the mean of absolute values of local SHAP
global_shap = {}
for col in all_shaps_df.columns:
    global_shap[col] = all_shaps_df[col].abs().mean()
global_shap_df = pd.DataFrame(global_shap, index=[0])
global_shap_df
# Out:
#    Latitude  Longitude  Random_1
# 0  0.116719   0.236866  0.001364

# %%
# Plot global SHAP
global_shap_plot(global_shap_df.iloc[0], global_shap_df.columns)

# %% [markdown]
# The Global SHAP tells us in general, the model finds Longitude having a much higher feature importance than Latitude. This is contradictory to our assumption as we would expect both Latitude and Longitude to be equally important in determining whether a city is in Asia.
#
# In the next section in this notebook I would explain why the SHAP value for Latitude was underestimated, and a possible resolution.

# %% [markdown]
# # Why the SHAP value for Latitude was underestimated?
#
# Remember from the begining, we created an imbalanced dataset.

# %%
# Bar plot for count of cities by continent
# Make sure we have a simulated imbalanced dataset
continent_counts = df['Continent'].value_counts()
continent_counts.plot(kind='bar', figsize=(10, 8))
plt.title('Number of Cities by Continent')
plt.xlabel('Continent')
plt.ylabel('Count')
plt.show()

# %%
# Check the distribution of model predictions

new_pos_df = test_df[test_df['pred']==1]
new_neg_df = test_df[test_df['pred']==0]


plt.scatter(new_pos_df['Latitude'], new_pos_df['Longitude'], label="Predicted Positives", alpha=0.6)
plt.scatter(new_neg_df['Latitude'], new_neg_df['Longitude'], label="Predicted Negatives", alpha=0.6)
plt.title('Latitude and Longitude')
plt.axvspan(new_pos_df['Latitude'].min(), new_pos_df['Latitude'].max(), alpha=0.2)
plt.axhspan(new_pos_df['Longitude'].min(), new_pos_df['Longitude'].max(), alpha=0.2)
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %% [markdown]
# Now, we can see that a significant amount of negative labeled cities with latitude falls into the blue region, which is the rage of lattiude that the model would predict a higher probability of city being in Asia.
#
# Using the training dataset as the background for SHAP calculation would make a biased result as the latitudes from the background are already likely to be in Asia. If we think about the employers A, B, C example again, we would need to estimate what happens if we have employer A/ B/ C working alone. However, in a model prediction we cannot remove a feature entirely, so the estimation on the marginal contribution would rely on a background data that is truly "meaningless".

# %% [markdown]
# # Resolution: use a self-defined baseline
#
# We can try to construct a self-defined baseline with Latitude and Longitude that are less meaningful. Let's try with North Pole (0, 0):

# %%
baseline = pd.DataFrame({
    'Latitude': [0, 90, -90, 0, 0],
    'Longitude': [0, 0, 0, 180, -180],
    'Random_1': [0, 0, 0, 0, 0]
})
baseline
# Out:
#    Latitude  Longitude  Random_1
# 0         0          0         0
# 1        90          0         0
# 2       -90          0         0
# 3         0        180         0
# 4         0       -180         0

# %%
# Check the distribution of model predictions and baseline

fp_df = test_df[(test_df['isAsia'] == 0) & (test_df['pred'] == 1)]
tp_df = test_df[(test_df['isAsia'] == 1) & (test_df['pred'] == 1)]
tn_df = test_df[(test_df['isAsia'] == 0) & (test_df['pred'] == 0)]

plt.scatter(tn_df['Latitude'], tn_df['Longitude'],
            label="True Negatives", alpha=0.5)
plt.scatter(tp_df['Latitude'], tp_df['Longitude'],
            label="True Positives", alpha=0.5)
plt.scatter(fp_df['Latitude'], fp_df['Longitude'],
            label="False Positives", alpha=0.5)
plt.scatter(baseline['Latitude'], baseline['Longitude'],
            label="Baseline", alpha=1)
plt.axvspan(new_pos_df['Latitude'].min(),
            new_pos_df['Latitude'].max(), alpha=0.2)
plt.axhspan(new_pos_df['Longitude'].min(),
            new_pos_df['Longitude'].max(), alpha=0.2)
plt.title('Latitude and Longitude')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
# Create a new SHAP Kernel Explainer
kernel_baseline_explainer = KernelExplainer(
    f,
    baseline.to_numpy(),
)
# Out:
# 1/1 [==============================] - 0s 18ms/step

# %%
# Check expected value of the baseline predictions
print(
    f"The expected value of Kernel explainer with self-defined baseline: {kernel_baseline_explainer.expected_value[0]}")
# Out:
# The expected value of Kernel explainer with self-defined baseline: 0.15232240234017808

# %% [markdown]
# This time we used a self-defined basline that scatters evenly on the plane. The expected value is similar to the training dataset, which is expected.

# %%
# Check prediction on the sample
shap_baseline_values = kernel_baseline_explainer.shap_values(sample.to_numpy())
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 15ms/step

# %%
shap.force_plot(kernel_baseline_explainer.expected_value,
                shap_baseline_values[0], sample)
# Out:
# <div id='i9DBTRC4HFX6QGMJSTF6S'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.15232240234017808, "outValue": 0.7731871008872986, "link": "identity", "featureNames": ["Latitude", "Longitude", "Random_1"], "features": {"0": {"effect": 0.26816375616093235, "value": 13.0827}, "1": {"effect": 0.3521599716236174, "value": 80.2707}, "2": {"effect": 0.0005409707625707583, "value": 0.10233442882782584}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('i9DBTRC4HFX6QGMJSTF6S')
#   );
# </script>

# %% [markdown]
# ## Global SHAP

# %%
start_time = time.time()
all_baseline_shap_values = kernel_baseline_explainer.shap_values(X_test)
end_time = time.time()
print(
    f"Computing SHAP for {X_test.shape[0]} records used time: {end_time - start_time} seconds"
)
# Out:
#   0%|          | 0/33 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 10ms/step
# Computing SHAP for 33 records used time: 1.7681410312652588 seconds

# %%
all_baseline_shap_values_df = pd.DataFrame(data=all_baseline_shap_values[0], columns=all_features)
# Compute global SHAP: the mean of absolute values of local SHAP
global_shap = {}
for col in all_baseline_shap_values_df.columns:
    global_shap[col] = all_baseline_shap_values_df[col].abs().mean()
global_shap_df = pd.DataFrame(global_shap, index=[0])
global_shap_df
# Out:
#    Latitude  Longitude  Random_1
# 0  0.153233   0.147945  0.000982

# %%
# Plot global SHAP
global_shap_plot(global_shap_df.iloc[0], global_shap_df.columns)

# %% [markdown]
# Now, we got the SHAP values for Latitude and Longitude similar to each other. This is because the SHAP computation is comparing with a "meaningless" baseline, so the marginal contribution from the two features would be equally high. Also note that the runtime reduced significantly as there are less iterations in the SHAP computation.

# %% [markdown]
# # Conclusion
#
# SHAP is a very useful computation to help us identify the feature importances and understand the model behavior. However, we should be careful in our interpretation on the results. Instead of simply saying "a high SHAP value indicates high feature importance", we should consider it as "the marginal contribution from the feature $x$ is high when comparing to its baseline values". Pay special attention to the imbalanced dataset as it may alter our interpretation on the SHAPs. We could produce a more reliable result with a self-defined "meaningless" baseline, and that would also have a better runtime than inputting the entire training dataset as the baseline.
